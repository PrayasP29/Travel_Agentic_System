# %% [markdown]
# # Multi-Agent Trip Planner
#
# Hackathon-friendly notebook entry point for a LangGraph-based trip planner using Groq, Tavily, and MCP-backed travel tools.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = (
    Path.cwd().parent
    if Path.cwd().name == "notebooks"
    else Path.cwd()
)

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

print("Project Root:", PROJECT_ROOT)
print("Python:", sys.executable)
# Out:
# Project Root: c:\Users\praya\Desktop\Tarvel_Agent\trip_planner
# Python: c:\Users\praya\Desktop\Tarvel_Agent\.venv\Scripts\python.exe

# %%
import sys

packages = [
    "groq",
    "langchain-groq",
    "langgraph",
    "langsmith",
    "tavily-python",
    "python-dotenv",
]

for pkg in packages:
    print(f"\n----- {pkg} -----")
    # !{sys.executable} -m pip show {pkg}
# Out:
# ----- groq -----
# Name: groq
# Version: 0.37.1
# Summary: The official Python library for the groq API
# Home-page: https://github.com/groq/groq-python
# Author:
# Author-email: Groq <support@groq.com>
# License: Apache-2.0
# Location: c:\Users\praya\Desktop\Tarvel_Agent\.venv\Lib\site-packages
# Requires: anyio, distro, httpx, pydantic, sniffio, typing-extensions
# Required-by: langchain-groq
#
# ----- langchain-groq -----
# Name: langchain-groq
# Version: 1.1.2
# Summary: An integration package connecting Groq and LangChain
# Home-page: https://docs.langchain.com/oss/python/integrations/providers/groq
# Author:
# Author-email:
# License: MIT
# Location: c:\Users\praya\Desktop\Tarvel_Agent\.venv\Lib\site-packages
# Requires: groq, langchain-core
# Required-by:
#
# ----- langgraph -----
# Name: langgraph
# Version: 1.2.2
# Summary: Building stateful, multi-actor applications with LLMs
# Home-page: https://docs.langchain.com/oss/python/langgraph/overview
# Author:
# Author-email:
# License-Expression: MIT
# Location: c:\Users\praya\Desktop\Tarvel_Agent\.venv\Lib\site-packages
# Requires: langchain-core, langgraph-checkpoint, langgraph-prebuilt, langgraph-sdk, pydantic, xxhash
# Required-by:
#
# ----- langsmith -----
# Name: langsmith
# Version: 0.8.7
# Summary: Client library to connect to the LangSmith Observability and Evaluation Platform.
# Home-page: https://smith.langchain.com/
# Author:
# Author-email: LangChain <support@langchain.dev>
# License: MIT
# Location: c:\Users\praya\Desktop\Tarvel_Agent\.venv\Lib\site-packages
# Requires: httpx, orjson, packaging, pydantic, requests, requests-toolbelt, uuid-utils, websockets, xxhash, zstandard
# Required-by: langchain-core
#
# ----- tavily-python -----
# Name: tavily-python
# Version: 0.7.25
# Summary: Python wrapper for the Tavily API
# Home-page: https://github.com/tavily-ai/tavily-python
# Author: Tavily AI
# Author-email: support@tavily.com
# License:
# Location: c:\Users\praya\Desktop\Tarvel_Agent\.venv\Lib\site-packages
# Requires: httpx, requests, tiktoken
# Required-by:
#
# ----- python-dotenv -----
# Name: python-dotenv
# Version: 1.2.2
# Summary: Read key-value pairs from a .env file and set them as environment variables
# Home-page:
# Author:
# Author-email: Saurabh Kumar <me+github@saurabh-kumar.com>
# License: BSD-3-Clause
# Location: c:\Users\praya\Desktop\Tarvel_Agent\.venv\Lib\site-packages
# Requires:
# Required-by: pydantic-settings

# %%
from dotenv import load_dotenv
import os

load_dotenv("../.env")

print("Groq Key Loaded:", bool(os.getenv("GROQ_API_KEY")))
print("Tavily Key Loaded:", bool(os.getenv("TAVILY_API_KEY")))
print("LangSmith Key Loaded:", bool(os.getenv("LANGCHAIN_API_KEY")))
# Out:
# Groq Key Loaded: True
# Tavily Key Loaded: True
# LangSmith Key Loaded: False

# %%
from groq import Groq
from langchain_groq import ChatGroq
from langgraph.graph import StateGraph
from langsmith import Client

print("All imports successful")
# Out:
# All imports successful

# %%
from config.settings import settings

print("Groq:", bool(settings.groq_api_key))
print("Tavily:", bool(settings.tavily_api_key))

print("Kiwi MCP:", settings.kiwi_mcp_server_url)
print("Weather MCP:", settings.gribstream_mcp_server_url)
print("Hotel MCP:", settings.agentorist_mcp_server_url)
# Out:
# Groq: True
# Tavily: True
# Kiwi MCP: https://mcp.kiwi.com
# Weather MCP: https://gribstream.com/mcp
# Hotel MCP: https://mcp.agentorist.com/mcp

# %%
from langchain_groq import ChatGroq
from config.settings import settings

llm = ChatGroq(
    model=settings.groq_text_model,
    groq_api_key=settings.groq_api_key
)

response = llm.invoke("Say hello in one sentence.")

print(response.content)
# Out:
# c:\Users\praya\Desktop\Tarvel_Agent\.venv\Lib\site-packages\langsmith\client.py:639: LangSmithMissingAPIKeyWarning: API key must be provided when using hosted LangSmith API
#   warnings.warn(
# Hello, it's nice to meet you and I'm here to help with any questions or topics you'd like to discuss.
# Failed to multipart ingest runs: langsmith.utils.LangSmithAuthError: Authentication failed for https://api.smith.langchain.com/runs/multipart. HTTPError('401 Client Error: Unauthorized for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Unauthorized"}\n')trace=019e74d2-fc18-7210-a7a7-19b05f387c2d,id=019e74d2-fc18-7210-a7a7-19b05f387c2d

# %%
from config.settings import get_settings

get_settings.cache_clear()
settings = get_settings()
print("Tracing:", settings.langchain_tracing)
print("API Key set:", bool(settings.langchain_api_key))
print("Project:", settings.langchain_project)
get_settings.cache_clear()
settings = get_settings()
print("Tracing:", settings.langchain_tracing)
print("API Key set:", bool(settings.langchain_api_key))
print("Project:", settings.langchain_project)
# Out:
# Tracing: True
# API Key set: True
# Project: TripPlanner
# Tracing: True
# API Key set: True
# Project: TripPlanner

# %%
from config.models import get_text_llm

llm = get_text_llm()

response = llm.invoke(
    "Reply with exactly: Groq Working"
)

print(response.content)
# Out:
# Groq Working

# %%
from config.settings import settings

print("LangSmith Key Exists:", bool(settings.langchain_api_key))
print("Project:", settings.langchain_project)
# Out:
# LangSmith Key Exists: False
# Project: TripPlanner

# %%
from config.settings import settings

print("Groq:", bool(settings.groq_api_key))
print("Tavily:", bool(settings.tavily_api_key))
print("LangSmith:", bool(settings.langchain_api_key))
# Out:
# Groq: True
# Tavily: True
# LangSmith: True

# %%
import os

print("LANGCHAIN_API_KEY set =", bool(os.getenv("LANGCHAIN_API_KEY")))
print("LANGCHAIN_PROJECT =", os.getenv("LANGCHAIN_PROJECT"))
# Out:
# LANGCHAIN_API_KEY set = True
# LANGCHAIN_PROJECT = TripPlanner

# %%
from state.trip_state import TripState

print("TripState Imported Successfully")
# Out:
# TripState Imported Successfully

# %%
sample_state: TripState = {
    "destination": "Mumbai",
    "venue": "DY Patil Stadium",
    "event_date": "2026-08-15",
    "flight_details": {},
    "hotel_details": {},
    "weather_details": {},
    "search_results": {},
    "itinerary": "",
    "status": "pending",
    "errors": []
}

sample_state
# Out:
# {'destination': 'Mumbai',
#  'venue': 'DY Patil Stadium',
#  'event_date': '2026-08-15',
#  'flight_details': {},
#  'hotel_details': {},
#  'weather_details': {},
#  'search_results': {},
#  'itinerary': '',
#  'status': 'pending',
#  'errors': []}

# %%
from tools.tavily_search import search_web

print("Import Successful")
# Out:
# Import Successful

# %%
results = search_web(
    "Best attractions in Mumbai"
)

type(results)

results
# Out:
# {'query': 'Best attractions in Mumbai',
#  'results': [{'url': 'https://www.tripadvisor.com/Attractions-g304554-Activities-Mumbai_Maharashtra.html',
#    'title': 'THE 15 BEST Things to Do in Mumbai (2026) - Must-See Attractions',
#    'content': 'Top Attractions in Mumbai · 1. Marine Drive · 4.5. (8,245). Points of Interest & Landmarks · 2. Shree Siddhivinayak · 4.6. (5,627). Religious Sites · 3. Gateway',
#    'score': 0.87218446,
#    'raw_content': None},
#   {'url': 'https://www.thrillophilia.com/places-to-visit-in-mumbai',
#    'title': '55 Places to Visit in Mumbai 2026, Tourist Places & Attractions',
#    'content': '## Tourist Places in Mumbai. Marine Drive,\xa0Gateway of India,\xa0Chowpatty Beach, Siddhivinayak Temple,\xa0Juhu Beach,\xa0Dharavi Slum,\xa0Worli Seaface,\xa0Haji Ali,\xa0Chhatrapati Shivaji Terminus , Aksa Beach, Versova Beach, Colaba Causeway Market, Chor Bazaar, Powai Lake , Kanheri Caves, Gorai Beach , Shivaji Park, ISKCON temple, Global Vipassana Pagoda, Mumbai Zoo and\xa0many more amazing tourist sights. From beaches to Bollywood and nature to nightlife, the City of Dreams lives up to its name featuring a dreamlike encounter for all the tourists. Serving just the right things to your platter, Mumbai is a city that will build its perspective on what you seek. For a party lover, Mumbai is all about clubs and ravishing parties, for a tranquillity seeker it is about the beautiful sunset over the Bandra Fort and the serene seashores, for a shopaholic the Linking Road and the Colaba Causeway will be their go-to place and for a person interested in history, the cultural heritage will be the best tourist places in Mumbai to entice.',
#    'score': 0.86713725,
#    'raw_content': None},
#   {'url': 'https://www.viator.com/Mumbai/d953',
#    'title': 'What to do in Mumbai? The 15 Best Attractions (June 2026) - Viator',
#    'content': 'From film studio tours to boat trips to the ancient temples at the Elephanta Caves. Many of the best things to do in Mumbai are situated in the southern part',
#    'score': 0.8302782,
#    'raw_content': None},
#   {'url': 'https://en.wikipedia.org/wiki/List_of_tourist_attractions_in_Mumbai',
#    'title': 'List of tourist attractions in Mumbai - Wikipedia',
#    'content': '# List of tourist attractions in Mumbai. *Find sources:*\xa0"List of tourist attractions in Mumbai"\xa0–\xa0news\xa0**·** newspapers\xa0**·** books\xa0**·** scholar\xa0**·** JSTOR *(March 2019)* *(Learn how and when to remove this message)* |. Mumbai, India has centuries of history and many sites of tourist interest. | * v * t * e  Tourist attractions in Mumbai (list) | |. N. Podar School * Sacred Heart Boys High School * Jamnabai Narsee School * Utpal Shanghvi Global School * Kendriya Vidyalaya Sangathan * Raja Shivaji Vidyalaya (King George High School) * St. Theresa\'s Boys High School * J.B. Petit High School for Girls | | Institutes for science and learning | * Tata Institute of Fundamental Research (TIFR) * Bhabha Atomic Research Centre (BARC) * Nehru Planetarium * Nehru Science Centre * Tata Institute of Social Sciences (TISS) * Centre for Excellence in Basic Sciences (UM-DAE CBS) | |.',
#    'score': 0.8138313,
#    'raw_content': None},
#   {'url': 'https://www.getyourguide.com/mumbai-l201/ttd',
#    'title': 'The BEST Things to Do in Mumbai - Top Activities in 2026 | GetYourGuide',
#    'content': "# Things to do in Mumbai. Grab vada pav, explore colonial-era landmarks, and ferry to the rock-cut Elephanta Caves, all powered by late-night energy. Mumbai: Full-Day Sightseeing Tour of Mumbai. Explore Mumbai on this guided tour with an expert driver guide or a dedicated tour guide, based on the tour option selected and travel in the comfort of an air-conditioned car. Mumbai: Elephanta Caves Half-Day Guided Tour with Expert. Discover the ancient culture and architecture surrounding the unmissable Elephanta Caves, a UNESCO World Heritage Site, on this tour. Discover Mumbai half or full-day tour with a driver & guide. But there are just as many things to do in Mumbai after dark.This guide to the top things to do in Mumbai at night is your map of the city's best after-dark activities, from late-night spots for authentic Indian cuisine to where to catch the sunset on the Arabian Sea.C. Edward Morgan • May 15, 2026.",
#    'score': 0.76659125,
#    'raw_content': None}]}
